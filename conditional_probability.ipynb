# %% [markdown]
# <h3 align="center">
#
# </h3>

# %% [markdown]
# In this notebook, we simulate **conditional distributions**, where one (or more) random variable(s) depend on one (or more) other random variables.
#
# We will see how the **Expected Values** can sometimes be calculated even when we do not have a clear probability distribution of that Random Variable.
#
# Finally, We will explore the nice case of **Bivariate Normal Distribution**, to see how $Y|X$ actually is a linear model.
